# %%
import pandas as pd
import matplotlib.pyplot as plt
trade_fairs= pd.read_csv(
    open('data-3895-2019-11-30.csv', 'r', encoding='cp1251'),
    sep=';'
)
trade_fairs.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ID</th>
#       <th>global_id</th>
#       <th>AdmArea</th>
#       <th>District</th>
#       <th>Address</th>
#       <th>RegionOfFair</th>
#       <th>PeriodOfPlacement</th>
#       <th>Goods</th>
#       <th>geoData</th>
#       <th>Unnamed: 9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>34</td>
#       <td>918223355</td>
#       <td>Восточный административный округ</td>
#       <td>район Гольяново</td>
#       <td>город Москва, Уральская улица, дом 4</td>
#       <td>Рязанская область</td>
#       <td>11.04.2019-17.04.2019</td>
#       <td>сельскохозяйственные, продовольственные и пром...</td>
#       <td>{type=Point, coordinates=[37.79885072650054, 5...</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>34</td>
#       <td>918223356</td>
#       <td>Восточный административный округ</td>
#       <td>район Гольяново</td>
#       <td>город Москва, Уральская улица, дом 4</td>
#       <td>Владимирская область</td>
#       <td>01.04.2019-07.04.2019</td>
#       <td>сельскохозяйственные, продовольственные и пром...</td>
#       <td>{type=Point, coordinates=[37.79885072650054, 5...</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>34</td>
#       <td>918223357</td>
#       <td>Восточный административный округ</td>
#       <td>район Гольяново</td>
#       <td>город Москва, Уральская улица, дом 4</td>
#       <td>Костромская область</td>
#       <td>01.04.2019-07.04.2019</td>
#       <td>сельскохозяйственные, продовольственные и пром...</td>
#       <td>{type=Point, coordinates=[37.79885072650054, 5...</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>34</td>
#       <td>918223358</td>
#       <td>Восточный административный округ</td>
#       <td>район Гольяново</td>
#       <td>город Москва, Уральская улица, дом 4</td>
#       <td>Республика Беларусь</td>
#       <td>21.04.2019-27.04.2019</td>
#       <td>сельскохозяйственные, продовольственные и пром...</td>
#       <td>{type=Point, coordinates=[37.79885072650054, 5...</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>35</td>
#       <td>918223359</td>
#       <td>Южный административный округ</td>
#       <td>район Царицыно</td>
#       <td>город Москва, Пролетарский проспект, дом 18</td>
#       <td>Ивановская область</td>
#       <td>11.04.2019-17.04.2019</td>
#       <td>сельскохозяйственные, продовольственные и пром...</td>
#       <td>{type=Point, coordinates=[37.656693306607316, ...</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
t1_count = trade_fairs.groupby(['District','PeriodOfPlacement']).size().sort_values(ascending=False).reset_index()
t2_count = trade_fairs.groupby(['AdmArea']).size().reset_index()

# %%
import matplotlib
matplotlib.style.use('ggplot')

t2_count.set_index('AdmArea').plot()
